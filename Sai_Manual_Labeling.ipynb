# %%
import pandas as pd
manual_labeling_sai = pd.read_csv('crowdsource_sai.csv')
manual_labeling_sai
# Out:
#     status                                              title  \
# 0      NEW                                     Data Scientist
# 1      NEW                  Data Scientist, Product Analytics
# 2      NEW                                           Big Data
# 3      NEW                 Vehicle Operator - Data Collection
# 4      NEW           Temporary Database/API back end designer
# ..     ...                                                ...
# 338    NEW                        Document Handler (Seasonal)
# 339    NEW                             Database Administrator
# 340    NEW               Power BI Analytics Consultant-Hybrid
# 341    NEW                                     Data Scientist
# 342    NEW  AI/machine learning for performance-enhancing ...
#
#                                          company                 location  \
# 0                        DEPARTMENT OF BUILDINGS      Manhattan, NY 10007
# 1                                           Meta  San Francisco, CA 94105
# 2                                    Sonsoft Inc               Durham, NC
# 3                              Applied Intuition        Mountain View, CA
# 4                North Carolina State University              Raleigh, NC
# ..                                           ...                      ...
# 338                    Southwest Solutions Group     Lewisville, TX 75056
# 339  Community Choice Financial Family of Brands     Carrollton, TX 75006
# 340                              Aries Solutions       New York, NY 11691
# 341                                          TPN               Irving, TX
# 342                         Princeton University      Princeton, NJ 08544
#
#            date                                              blurb  \
# 0    2024-11-14  Performs data cleaning & validation in order t...
# 1    2024-10-29  Communication and influence: You won't simply ...
# 2    2024-10-09  Experience in processing structured data - War...
# 3    2024-11-04  In this role, you will play a critical part in...
# 4    2024-10-09  A database/API designer for overhauling the ba...
# ..          ...                                                ...
# 338  2024-10-23  Hours: This is a seasonal 5-month full-time po...
# 339  2024-11-01  Backup and restore data to prevent data loss. ...
# 340  2024-11-04  Support and develop activities related to end-...
# 341  2024-10-05  Build scalable data pipelines, ensuring seamle...
# 342  2024-11-12  This opportunity will prepare the incumbent fo...
#
#                                                   tags  \
# 0    Job types: Full-time\r\nBenefits: Work from ho...
# 1                                                  NaN
# 2    Job types: Full-time\r\nJob types cc: Permanen...
# 3    Job types: Full-time, Contract\r\nBenefits: Co...
# 4      Job types: Temporary\r\nJob types cc: Temporary
# ..                                                 ...
# 338  Job types: Full-time\r\nShifts: 8 hour shift\r...
# 339  Job types: Full-time\r\nBenefits: Wellness pro...
# 340  Job types: Contract\r\nShifts: 8 hour shift\r\...
# 341    Job types: Full-time\r\nJob types cc: Full-time
# 342                                                NaN
#
#                                                   link  \
# 0    https://www.indeed.com/m/viewjob?jk=9672782736...
# 1    https://www.indeed.com/m/viewjob?jk=e76ea3072d...
# 2    https://www.indeed.com/m/viewjob?jk=d93e2aa0e9...
# 3    https://www.indeed.com/m/viewjob?jk=f6891a8394...
# 4    https://www.indeed.com/m/viewjob?jk=13f3f2c8ec...
# ..                                                 ...
# 338  https://www.indeed.com/m/viewjob?jk=19ff80b60e...
# 339  https://www.indeed.com/m/viewjob?jk=875528445c...
# 340  https://www.indeed.com/m/viewjob?jk=9f9548b001...
# 341  https://www.indeed.com/m/viewjob?jk=4174535bc7...
# 342  https://www.indeed.com/m/viewjob?jk=3d620a3abe...
#
#                                        id             provider query  \
# 0    IndeedScraperUSAEng_9672782736a820ae  IndeedScraperUSAEng  Data
# 1    IndeedScraperUSAEng_e76ea3072dcb4f67  IndeedScraperUSAEng  Data
# 2    IndeedScraperUSAEng_d93e2aa0e9fb3f09  IndeedScraperUSAEng  Data
# 3    IndeedScraperUSAEng_f6891a83944e65de  IndeedScraperUSAEng  Data
# 4    IndeedScraperUSAEng_13f3f2c8ec0ebaf5  IndeedScraperUSAEng  Data
# ..                                    ...                  ...   ...
# 338  IndeedScraperUSAEng_19ff80b60ed75523  IndeedScraperUSAEng  Data
# 339  IndeedScraperUSAEng_875528445ca15d46  IndeedScraperUSAEng  Data
# 340  IndeedScraperUSAEng_9f9548b001fe4f86  IndeedScraperUSAEng  Data
# 341  IndeedScraperUSAEng_4174535bc72862a9  IndeedScraperUSAEng  Data
# 342  IndeedScraperUSAEng_3d620a3abe446c71  IndeedScraperUSAEng  Data
#
#           locale                      wage          remoteness  state_zip  \
# 0    USA_ENGLISH    $79473 - $91394 yearly             UNKNOWN   NY 10007
# 1    USA_ENGLISH  $173000 - $242000 yearly             UNKNOWN   CA 94105
# 2    USA_ENGLISH                       NaN             UNKNOWN         NC
# 3    USA_ENGLISH          $20 - $25 hourly             UNKNOWN         CA
# 4    USA_ENGLISH          $55 - $60 hourly             UNKNOWN         NC
# ..           ...                       ...                 ...        ...
# 338  USA_ENGLISH          $16 - $-1 hourly             UNKNOWN   TX 75056
# 339  USA_ENGLISH                       NaN             UNKNOWN   TX 75006
# 340  USA_ENGLISH          $55 - $60 hourly  TEMPORARILY_REMOTE   NY 11691
# 341  USA_ENGLISH                       NaN             UNKNOWN         TX
# 342  USA_ENGLISH                       NaN             UNKNOWN   NJ 08544
#
#     state           city      job_level
# 0      NY      Manhattan  Uncategorized
# 1      CA  San Francisco  Uncategorized
# 2      NC         Durham  Uncategorized
# 3      CA  Mountain View  Uncategorized
# 4      NC        Raleigh  Uncategorized
# ..    ...            ...            ...
# 338    TX     Lewisville  Uncategorized
# 339    TX     Carrollton  Uncategorized
# 340    NY       New York  Uncategorized
# 341    TX         Irving  Uncategorized
# 342    NJ      Princeton  Uncategorized
#
# [343 rows x 18 columns]

# %%
# Define keywords for job levels
entry_keywords = [' i ','staff', 'dba', 'junior', 'assistant', 'entry', 'graduate', 'intern', 'trainee', 'aide','collector','technician' ]
mid_keywords = [' ii','mid', 'associate', 'specialist', 'coordinator', 'analyst', 'engineer', 'developer']
senior_keywords = ['mentor', 'supervisor', 'sr. ','head ','sr ', 'president', ' iii','senior', 'lead', 'manager', 'director', 'principal', 'executive', 'chief']

# Function to label job levels based on the title and blurb
def label_job_level(row):
    title = str(row['title']).lower()
    blurb = str(row['blurb']).lower()

    if any(keyword in title or keyword in blurb for keyword in senior_keywords):
        return 'Senior-Level'
    elif any(keyword in title or keyword in blurb for keyword in mid_keywords):
        return 'Mid-Level'
    elif any(keyword in title or keyword in blurb for keyword in entry_keywords):
        return 'Entry-Level'
    else:
        return 'Uncategorized'

# Apply the labeling function
manual_labeling_sai['job_level'] = manual_labeling_sai.apply(label_job_level, axis=1)

# Count job levels for an overview
job_level_counts = manual_labeling_sai['job_level'].value_counts()
job_level_counts
# Out:
# job_level
# Uncategorized    343
# Name: count, dtype: int64

# %%
uncat = manual_labeling_sai[manual_labeling_sai['job_level'].str.contains('Uncategorized')]
uncat
# Out:
#     status                                              title  \
# 0      NEW                                     Data Scientist
# 1      NEW                  Data Scientist, Product Analytics
# 2      NEW                                           Big Data
# 3      NEW                 Vehicle Operator - Data Collection
# 4      NEW           Temporary Database/API back end designer
# ..     ...                                                ...
# 338    NEW                        Document Handler (Seasonal)
# 339    NEW                             Database Administrator
# 340    NEW               Power BI Analytics Consultant-Hybrid
# 341    NEW                                     Data Scientist
# 342    NEW  AI/machine learning for performance-enhancing ...
#
#                                          company                 location  \
# 0                        DEPARTMENT OF BUILDINGS      Manhattan, NY 10007
# 1                                           Meta  San Francisco, CA 94105
# 2                                    Sonsoft Inc               Durham, NC
# 3                              Applied Intuition        Mountain View, CA
# 4                North Carolina State University              Raleigh, NC
# ..                                           ...                      ...
# 338                    Southwest Solutions Group     Lewisville, TX 75056
# 339  Community Choice Financial Family of Brands     Carrollton, TX 75006
# 340                              Aries Solutions       New York, NY 11691
# 341                                          TPN               Irving, TX
# 342                         Princeton University      Princeton, NJ 08544
#
#            date                                              blurb  \
# 0    2024-11-14  Performs data cleaning & validation in order t...
# 1    2024-10-29  Communication and influence: You won't simply ...
# 2    2024-10-09  Experience in processing structured data - War...
# 3    2024-11-04  In this role, you will play a critical part in...
# 4    2024-10-09  A database/API designer for overhauling the ba...
# ..          ...                                                ...
# 338  2024-10-23  Hours: This is a seasonal 5-month full-time po...
# 339  2024-11-01  Backup and restore data to prevent data loss. ...
# 340  2024-11-04  Support and develop activities related to end-...
# 341  2024-10-05  Build scalable data pipelines, ensuring seamle...
# 342  2024-11-12  This opportunity will prepare the incumbent fo...
#
#                                                   tags  \
# 0    Job types: Full-time\r\nBenefits: Work from ho...
# 1                                                  NaN
# 2    Job types: Full-time\r\nJob types cc: Permanen...
# 3    Job types: Full-time, Contract\r\nBenefits: Co...
# 4      Job types: Temporary\r\nJob types cc: Temporary
# ..                                                 ...
# 338  Job types: Full-time\r\nShifts: 8 hour shift\r...
# 339  Job types: Full-time\r\nBenefits: Wellness pro...
# 340  Job types: Contract\r\nShifts: 8 hour shift\r\...
# 341    Job types: Full-time\r\nJob types cc: Full-time
# 342                                                NaN
#
#                                                   link  \
# 0    https://www.indeed.com/m/viewjob?jk=9672782736...
# 1    https://www.indeed.com/m/viewjob?jk=e76ea3072d...
# 2    https://www.indeed.com/m/viewjob?jk=d93e2aa0e9...
# 3    https://www.indeed.com/m/viewjob?jk=f6891a8394...
# 4    https://www.indeed.com/m/viewjob?jk=13f3f2c8ec...
# ..                                                 ...
# 338  https://www.indeed.com/m/viewjob?jk=19ff80b60e...
# 339  https://www.indeed.com/m/viewjob?jk=875528445c...
# 340  https://www.indeed.com/m/viewjob?jk=9f9548b001...
# 341  https://www.indeed.com/m/viewjob?jk=4174535bc7...
# 342  https://www.indeed.com/m/viewjob?jk=3d620a3abe...
#
#                                        id             provider query  \
# 0    IndeedScraperUSAEng_9672782736a820ae  IndeedScraperUSAEng  Data
# 1    IndeedScraperUSAEng_e76ea3072dcb4f67  IndeedScraperUSAEng  Data
# 2    IndeedScraperUSAEng_d93e2aa0e9fb3f09  IndeedScraperUSAEng  Data
# 3    IndeedScraperUSAEng_f6891a83944e65de  IndeedScraperUSAEng  Data
# 4    IndeedScraperUSAEng_13f3f2c8ec0ebaf5  IndeedScraperUSAEng  Data
# ..                                    ...                  ...   ...
# 338  IndeedScraperUSAEng_19ff80b60ed75523  IndeedScraperUSAEng  Data
# 339  IndeedScraperUSAEng_875528445ca15d46  IndeedScraperUSAEng  Data
# 340  IndeedScraperUSAEng_9f9548b001fe4f86  IndeedScraperUSAEng  Data
# 341  IndeedScraperUSAEng_4174535bc72862a9  IndeedScraperUSAEng  Data
# 342  IndeedScraperUSAEng_3d620a3abe446c71  IndeedScraperUSAEng  Data
#
#           locale                      wage          remoteness  state_zip  \
# 0    USA_ENGLISH    $79473 - $91394 yearly             UNKNOWN   NY 10007
# 1    USA_ENGLISH  $173000 - $242000 yearly             UNKNOWN   CA 94105
# 2    USA_ENGLISH                       NaN             UNKNOWN         NC
# 3    USA_ENGLISH          $20 - $25 hourly             UNKNOWN         CA
# 4    USA_ENGLISH          $55 - $60 hourly             UNKNOWN         NC
# ..           ...                       ...                 ...        ...
# 338  USA_ENGLISH          $16 - $-1 hourly             UNKNOWN   TX 75056
# 339  USA_ENGLISH                       NaN             UNKNOWN   TX 75006
# 340  USA_ENGLISH          $55 - $60 hourly  TEMPORARILY_REMOTE   NY 11691
# 341  USA_ENGLISH                       NaN             UNKNOWN         TX
# 342  USA_ENGLISH                       NaN             UNKNOWN   NJ 08544
#
#     state           city      job_level
# 0      NY      Manhattan  Uncategorized
# 1      CA  San Francisco  Uncategorized
# 2      NC         Durham  Uncategorized
# 3      CA  Mountain View  Uncategorized
# 4      NC        Raleigh  Uncategorized
# ..    ...            ...            ...
# 338    TX     Lewisville  Uncategorized
# 339    TX     Carrollton  Uncategorized
# 340    NY       New York  Uncategorized
# 341    TX         Irving  Uncategorized
# 342    NJ      Princeton  Uncategorized
#
# [343 rows x 18 columns]

# %%
labeled = uncat.copy()

# %%
labeled.loc[labeled['id'] == 'IndeedScraperUSAEng_9672782736a820ae', 'job_level'] = 'Uncategorized'
labeled
# Out:
#     status                                              title  \
# 0      NEW                                     Data Scientist
# 1      NEW                  Data Scientist, Product Analytics
# 2      NEW                                           Big Data
# 3      NEW                 Vehicle Operator - Data Collection
# 4      NEW           Temporary Database/API back end designer
# ..     ...                                                ...
# 338    NEW                        Document Handler (Seasonal)
# 339    NEW                             Database Administrator
# 340    NEW               Power BI Analytics Consultant-Hybrid
# 341    NEW                                     Data Scientist
# 342    NEW  AI/machine learning for performance-enhancing ...
#
#                                          company                 location  \
# 0                        DEPARTMENT OF BUILDINGS      Manhattan, NY 10007
# 1                                           Meta  San Francisco, CA 94105
# 2                                    Sonsoft Inc               Durham, NC
# 3                              Applied Intuition        Mountain View, CA
# 4                North Carolina State University              Raleigh, NC
# ..                                           ...                      ...
# 338                    Southwest Solutions Group     Lewisville, TX 75056
# 339  Community Choice Financial Family of Brands     Carrollton, TX 75006
# 340                              Aries Solutions       New York, NY 11691
# 341                                          TPN               Irving, TX
# 342                         Princeton University      Princeton, NJ 08544
#
#            date                                              blurb  \
# 0    2024-11-14  Performs data cleaning & validation in order t...
# 1    2024-10-29  Communication and influence: You won't simply ...
# 2    2024-10-09  Experience in processing structured data - War...
# 3    2024-11-04  In this role, you will play a critical part in...
# 4    2024-10-09  A database/API designer for overhauling the ba...
# ..          ...                                                ...
# 338  2024-10-23  Hours: This is a seasonal 5-month full-time po...
# 339  2024-11-01  Backup and restore data to prevent data loss. ...
# 340  2024-11-04  Support and develop activities related to end-...
# 341  2024-10-05  Build scalable data pipelines, ensuring seamle...
# 342  2024-11-12  This opportunity will prepare the incumbent fo...
#
#                                                   tags  \
# 0    Job types: Full-time\r\nBenefits: Work from ho...
# 1                                                  NaN
# 2    Job types: Full-time\r\nJob types cc: Permanen...
# 3    Job types: Full-time, Contract\r\nBenefits: Co...
# 4      Job types: Temporary\r\nJob types cc: Temporary
# ..                                                 ...
# 338  Job types: Full-time\r\nShifts: 8 hour shift\r...
# 339  Job types: Full-time\r\nBenefits: Wellness pro...
# 340  Job types: Contract\r\nShifts: 8 hour shift\r\...
# 341    Job types: Full-time\r\nJob types cc: Full-time
# 342                                                NaN
#
#                                                   link  \
# 0    https://www.indeed.com/m/viewjob?jk=9672782736...
# 1    https://www.indeed.com/m/viewjob?jk=e76ea3072d...
# 2    https://www.indeed.com/m/viewjob?jk=d93e2aa0e9...
# 3    https://www.indeed.com/m/viewjob?jk=f6891a8394...
# 4    https://www.indeed.com/m/viewjob?jk=13f3f2c8ec...
# ..                                                 ...
# 338  https://www.indeed.com/m/viewjob?jk=19ff80b60e...
# 339  https://www.indeed.com/m/viewjob?jk=875528445c...
# 340  https://www.indeed.com/m/viewjob?jk=9f9548b001...
# 341  https://www.indeed.com/m/viewjob?jk=4174535bc7...
# 342  https://www.indeed.com/m/viewjob?jk=3d620a3abe...
#
#                                        id             provider query  \
# 0    IndeedScraperUSAEng_9672782736a820ae  IndeedScraperUSAEng  Data
# 1    IndeedScraperUSAEng_e76ea3072dcb4f67  IndeedScraperUSAEng  Data
# 2    IndeedScraperUSAEng_d93e2aa0e9fb3f09  IndeedScraperUSAEng  Data
# 3    IndeedScraperUSAEng_f6891a83944e65de  IndeedScraperUSAEng  Data
# 4    IndeedScraperUSAEng_13f3f2c8ec0ebaf5  IndeedScraperUSAEng  Data
# ..                                    ...                  ...   ...
# 338  IndeedScraperUSAEng_19ff80b60ed75523  IndeedScraperUSAEng  Data
# 339  IndeedScraperUSAEng_875528445ca15d46  IndeedScraperUSAEng  Data
# 340  IndeedScraperUSAEng_9f9548b001fe4f86  IndeedScraperUSAEng  Data
# 341  IndeedScraperUSAEng_4174535bc72862a9  IndeedScraperUSAEng  Data
# 342  IndeedScraperUSAEng_3d620a3abe446c71  IndeedScraperUSAEng  Data
#
#           locale                      wage          remoteness  state_zip  \
# 0    USA_ENGLISH    $79473 - $91394 yearly             UNKNOWN   NY 10007
# 1    USA_ENGLISH  $173000 - $242000 yearly             UNKNOWN   CA 94105
# 2    USA_ENGLISH                       NaN             UNKNOWN         NC
# 3    USA_ENGLISH          $20 - $25 hourly             UNKNOWN         CA
# 4    USA_ENGLISH          $55 - $60 hourly             UNKNOWN         NC
# ..           ...                       ...                 ...        ...
# 338  USA_ENGLISH          $16 - $-1 hourly             UNKNOWN   TX 75056
# 339  USA_ENGLISH                       NaN             UNKNOWN   TX 75006
# 340  USA_ENGLISH          $55 - $60 hourly  TEMPORARILY_REMOTE   NY 11691
# 341  USA_ENGLISH                       NaN             UNKNOWN         TX
# 342  USA_ENGLISH                       NaN             UNKNOWN   NJ 08544
#
#     state           city      job_level
# 0      NY      Manhattan  Uncategorized
# 1      CA  San Francisco  Uncategorized
# 2      NC         Durham  Uncategorized
# 3      CA  Mountain View  Uncategorized
# 4      NC        Raleigh  Uncategorized
# ..    ...            ...            ...
# 338    TX     Lewisville  Uncategorized
# 339    TX     Carrollton  Uncategorized
# 340    NY       New York  Uncategorized
# 341    TX         Irving  Uncategorized
# 342    NJ      Princeton  Uncategorized
#
# [343 rows x 18 columns]
