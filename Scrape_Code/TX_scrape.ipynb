# %%
pip install git+https://github.com/PaulMcInnis/JobFunnel.git
# Out:
# ...
#   Cloning https://github.com/PaulMcInnis/JobFunnel.git to c:\users\panth\appdata\local\temp\pip-req-build-guomh8jj
#   Resolved https://github.com/PaulMcInnis/JobFunnel.git to commit 493af1bbdc8b846b630a1b0e2cedb2eb02ab7f4d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/PaulMcInnis/JobFunnel.git 'C:\Users\panth\AppData\Local\Temp\pip-req-build-guomh8jj'

# %%
#!pip install wget
import wget

# %%
#!pip install pyyaml
import yaml

# %%
# !wget https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/Query_Files/TX_query.yaml -O TX_Jobs.yaml
# Out:
# --2024-11-19 13:39:47--  https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/Query_Files/TX_query.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2320 (2.3K) [text/plain]
# Saving to: 'TX_Jobs.yaml'
#
#      0K ..                                                    100%  216K=0.01s
#
# 2024-11-19 13:39:48 (216 KB/s) - 'TX_Jobs.yaml' saved [2320/2320]

# %%
# !funnel load -s TX_Jobs.yaml
# Out:
# [2024-11-19 13:39:52,891] [INFO] JobFunnel: Scraping local providers with: ['IndeedScraperUSAEng', 'MonsterScraperUSAEng']
# [2024-11-19 13:39:54,047] [INFO] IndeedScraperUSAEng: Found 40 pages of search results for query=Data
# [2024-11-19 13:40:07,159] [INFO] IndeedScraperUSAEng: Scraped 979 job listings from search results pages
# [2024-11-19 13:40:08,923] [ERROR] IndeedScraperUSAEng: Job WIT Liaison - Biligual Preferred (Redbird) Onsite and WIT Liaison - Biligual Preferred (Redbird) Onsite share duplicate key_id: IndeedScraperUSAEng_88e2ce686d44c7cc
# [2024-11-19 13:40:08,925] [ERROR] IndeedScraperUSAEng: Job Solutions Architect | Data Center | Network (Remote) and Solutions Architect | Data Center | Network (Remote) share duplicate key_id: IndeedScraperUSAEng_f78438fef71d95b4
# [2024-11-19 13:40:08,925] [ERROR] IndeedScraperUSAEng: Job Data Scientist and Data Scientist share duplicate key_id: IndeedScraperUSAEng_493724232038bceb
# ...
