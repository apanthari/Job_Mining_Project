# %%
pip install git+https://github.com/PaulMcInnis/JobFunnel.git
# Out:
# ...
#   Cloning https://github.com/PaulMcInnis/JobFunnel.git to c:\users\panth\appdata\local\temp\pip-req-build-tfpcx5j3
#   Resolved https://github.com/PaulMcInnis/JobFunnel.git to commit 493af1bbdc8b846b630a1b0e2cedb2eb02ab7f4d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/PaulMcInnis/JobFunnel.git 'C:\Users\panth\AppData\Local\Temp\pip-req-build-tfpcx5j3'

# %%
#!pip install wget
import wget

# %%
#!pip install pyyaml
import yaml

# %%
# !wget https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/SF_Query.yaml -O USA_Jobs.yaml
# Out:
# --2024-11-05 12:56:55--  https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/SF_Query.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2330 (2.3K) [text/plain]
# Saving to: 'USA_Jobs.yaml'
#
#      0K ..                                                    100%  163K=0.01s
#
# 2024-11-05 12:56:55 (163 KB/s) - 'USA_Jobs.yaml' saved [2330/2330]

# %%
# !funnel load -s USA_Jobs.yaml
# Out:
# [2024-11-05 12:56:58,333] [INFO] JobFunnel: Scraping local providers with: ['IndeedScraperUSAEng', 'MonsterScraperUSAEng']
# [2024-11-05 12:56:59,552] [INFO] IndeedScraperUSAEng: Found 100 pages of search results for query=Data
# [2024-11-05 12:57:15,425] [INFO] IndeedScraperUSAEng: Scraped 2497 job listings from search results pages
# [2024-11-05 12:57:16,620] [ERROR] IndeedScraperUSAEng: Job Senior Distinguished I, Data Scientist | Intelligent Store Team and Senior Distinguished I, Data Scientist | Intelligent Store Team share duplicate key_id: IndeedScraperUSAEng_ae03277fff7ed475
# [2024-11-05 12:57:16,647] [ERROR] IndeedScraperUSAEng: Job Senior, Data Scientist - Machine Learning Engineer and Senior, Data Scientist - Machine Learning Engineer share duplicate key_id: IndeedScraperUSAEng_74291f4bf2d08a40
# ...
