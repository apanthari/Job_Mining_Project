# %%
pip install git+https://github.com/PaulMcInnis/JobFunnel.git
# Out:
# ...
#
#   Cloning https://github.com/PaulMcInnis/JobFunnel.git to c:\users\panth\appdata\local\temp\pip-req-build-ohllensk
#   Resolved https://github.com/PaulMcInnis/JobFunnel.git to commit 493af1bbdc8b846b630a1b0e2cedb2eb02ab7f4d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/PaulMcInnis/JobFunnel.git 'C:\Users\panth\AppData\Local\Temp\pip-req-build-ohllensk'

# %%
#!pip install wget
import wget

# %%
#!pip install pyyaml
import yaml

# %%
# !wget https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/NC_query.yaml -O NC_Jobs.yaml
# Out:
# --2024-11-05 13:06:51--  https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/NC_query.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2321 (2.3K) [text/plain]
# Saving to: 'NC_Jobs.yaml'
#
#      0K ..                                                    100%  353K=0.006s
#
# 2024-11-05 13:06:52 (353 KB/s) - 'NC_Jobs.yaml' saved [2321/2321]

# %%
# !funnel load -s NC_Jobs.yaml
# Out:
# [2024-11-05 13:06:55,620] [INFO] JobFunnel: Scraping local providers with: ['IndeedScraperUSAEng', 'MonsterScraperUSAEng']
# [2024-11-05 13:06:56,923] [INFO] IndeedScraperUSAEng: Found 10 pages of search results for query=Data
# [2024-11-05 13:06:59,457] [INFO] IndeedScraperUSAEng: Scraped 250 job listings from search results pages
# [2024-11-05 13:06:59,552] [ERROR] IndeedScraperUSAEng: Job Sr. Administrator, HR Ops - Employee Data Mgmt (Greensboro, NC) and Sr. Administrator, HR Ops - Employee Data Mgmt (Greensboro, NC) share duplicate key_id: IndeedScraperUSAEng_8cbce88f6320a153
# [2024-11-05 13:06:59,552] [ERROR] IndeedScraperUSAEng: Job Temporary Data and AI at Work Instructor and Temporary Data and AI at Work Instructor share duplicate key_id: IndeedScraperUSAEng_a88bc29282744fb7
# ...
