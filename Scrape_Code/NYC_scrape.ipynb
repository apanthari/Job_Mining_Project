# %%
pip install git+https://github.com/PaulMcInnis/JobFunnel.git
# Out:
# ...
#   Cloning https://github.com/PaulMcInnis/JobFunnel.git to c:\users\panth\appdata\local\temp\pip-req-build-mzc0x8d7
#   Resolved https://github.com/PaulMcInnis/JobFunnel.git to commit 493af1bbdc8b846b630a1b0e2cedb2eb02ab7f4d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/PaulMcInnis/JobFunnel.git 'C:\Users\panth\AppData\Local\Temp\pip-req-build-mzc0x8d7'

# %%
#!pip install wget
import wget

# %%
#!pip install pyyaml
import yaml

# %%
# !wget https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/Query_Files/NYC_Query.yaml -O NYC_Jobs.yaml
# Out:
# --2024-11-08 15:48:57--  https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/Query_Files/NYC_Query.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2330 (2.3K) [text/plain]
# Saving to: 'NYC_Jobs.yaml'
#
#      0K ..                                                    100%  243K=0.009s
#
# 2024-11-08 15:48:57 (243 KB/s) - 'NYC_Jobs.yaml' saved [2330/2330]

# %%
# !funnel load -s NYC_Jobs.yaml
# Out:
# [2024-11-08 15:49:00,038] [INFO] JobFunnel: Scraping local providers with: ['IndeedScraperUSAEng', 'MonsterScraperUSAEng']
# [2024-11-08 15:49:01,758] [INFO] IndeedScraperUSAEng: Found 250 pages of search results for query=Data
# [2024-11-08 15:50:44,014] [INFO] IndeedScraperUSAEng: Scraped 6235 job listings from search results pages
# [2024-11-08 15:50:47,315] [ERROR] IndeedScraperUSAEng: Job Fashion Data Coordinator and Fashion Data Coordinator share duplicate key_id: IndeedScraperUSAEng_09ce8c2723ada808
# [2024-11-08 15:50:47,318] [ERROR] IndeedScraperUSAEng: Job Data Engineer and Data Engineer share duplicate key_id: IndeedScraperUSAEng_b22948e94e8c6af0
# [2024-11-08 15:50:47,320] [ERROR] IndeedScraperUSAEng: Job Data Scientist Lead and Data Scientist Lead share duplicate key_id: IndeedScraperUSAEng_c8ecb3ae27af87a3
# ...
