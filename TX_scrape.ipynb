# %%
pip install git+https://github.com/PaulMcInnis/JobFunnel.git
# Out:
# ...
#   Cloning https://github.com/PaulMcInnis/JobFunnel.git to c:\users\panth\appdata\local\temp\pip-req-build-guomh8jj
#   Resolved https://github.com/PaulMcInnis/JobFunnel.git to commit 493af1bbdc8b846b630a1b0e2cedb2eb02ab7f4d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/PaulMcInnis/JobFunnel.git 'C:\Users\panth\AppData\Local\Temp\pip-req-build-guomh8jj'

# %%
# !pip install wget
import wget

# %%
# !pip install pyyaml
import yaml

# %%
# !wget https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/TX_query.yaml -O TX_Jobs.yaml
# Out:
# --2024-11-02 11:17:08--  https://raw.githubusercontent.com/apanthari/Job_Mining_Project/refs/heads/main/TX_query.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2320 (2.3K) [text/plain]
# Saving to: 'TX_Jobs.yaml'
#
#      0K ..                                                    100%  334K=0.007s
#
# 2024-11-02 11:17:08 (334 KB/s) - 'TX_Jobs.yaml' saved [2320/2320]

# %%
# !funnel load -s TX_Jobs.yaml
# Out:
# [2024-11-02 11:17:11,570] [INFO] JobFunnel: Scraping local providers with: ['IndeedScraperUSAEng', 'MonsterScraperUSAEng']
# [2024-11-02 11:17:13,044] [INFO] IndeedScraperUSAEng: Found 40 pages of search results for query=Data
# [2024-11-02 11:17:26,275] [INFO] IndeedScraperUSAEng: Scraped 984 job listings from search results pages
# [2024-11-02 11:17:27,572] [ERROR] IndeedScraperUSAEng: Job Data Entry Specialist and Data Entry Specialist share duplicate key_id: IndeedScraperUSAEng_3caa18b3f97491c5
# [2024-11-02 11:17:27,585] [ERROR] IndeedScraperUSAEng: Job CLERK IV.6001100 and CLERK IV.6001100 share duplicate key_id: IndeedScraperUSAEng_489b1479bc329826
# [2024-11-02 11:17:27,587] [ERROR] IndeedScraperUSAEng: Job Marketing Analytics Lead - Data & Reporting and Marketing Analytics Lead - Data & Reporting share duplicate key_id: IndeedScraperUSAEng_6dd1a26bf54da412
# ...
